# %%
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
import os
import matplotlib.pyplot as plt
import seaborn as sns
import random

# ======================================================
# CONFIG
# ======================================================

IMG_SIZE = 224
BATCH_SIZE = 32
EPOCHS = 70
NUM_CLASSES = 3
output_dir = "/kaggle/working"

train_dir = "/kaggle/input/datasets/hitakshigabani/dataset-tb-and-pneumoniadetection/chest-xray-dataset/train_balanced"
val_dir = "/kaggle/input/datasets/hitakshigabani/dataset-tb-and-pneumoniadetection/chest-xray-dataset/val"
test_dir = "/kaggle/input/datasets/hitakshigabani/dataset-tb-and-pneumoniadetection/chest-xray-dataset/test"

# ======================================================
# DATA GENERATORS
# ======================================================

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=8,
    zoom_range=0.08,
    horizontal_flip=True
)

val_test_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

val_gen = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

test_gen = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=1,
    class_mode='categorical',
    shuffle=False
)

# ======================================================
# MODEL (DenseNet121 from scratch)
# ======================================================

weight_decay = 1e-4

def dense_block(x, num_layers, growth_rate):
    for _ in range(num_layers):
        cb = layers.BatchNormalization()(x)
        cb = layers.ReLU()(cb)
        cb = layers.Conv2D(4 * growth_rate, (1,1),
                           padding='same',
                           use_bias=False,
                           kernel_regularizer=regularizers.l2(weight_decay))(cb)

        cb = layers.BatchNormalization()(cb)
        cb = layers.ReLU()(cb)
        cb = layers.Conv2D(growth_rate, (3,3),
                           padding='same',
                           use_bias=False,
                           kernel_regularizer=regularizers.l2(weight_decay))(cb)

        x = layers.Concatenate()([x, cb])
    return x


def transition_block(x, reduction):
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.Conv2D(int(tf.keras.backend.int_shape(x)[-1] * reduction),
                      (1,1),
                      padding='same',
                      use_bias=False,
                      kernel_regularizer=regularizers.l2(weight_decay))(x)
    x = layers.AveragePooling2D((2,2), strides=(2,2))(x)
    return x


def build_densenet121(input_shape=(224,224,3), classes=3):
    inputs = layers.Input(shape=input_shape)

    x = layers.ZeroPadding2D((3,3))(inputs)
    x = layers.Conv2D(64, (7,7), strides=(2,2),
                      use_bias=False,
                      kernel_regularizer=regularizers.l2(weight_decay))(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.MaxPooling2D((3,3), strides=(2,2), padding='same')(x)

    x = dense_block(x, 6, 32)
    x = transition_block(x, 0.5)

    x = dense_block(x, 12, 32)
    x = transition_block(x, 0.5)

    x = dense_block(x, 24, 32)
    x = transition_block(x, 0.5)

    x = dense_block(x, 16, 32)

    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.35)(x)

    outputs = layers.Dense(classes,
                           activation='softmax',
                           kernel_regularizer=regularizers.l2(weight_decay))(x)

    return models.Model(inputs, outputs)

model = build_densenet121(classes=NUM_CLASSES)

# ======================================================
# CLASS WEIGHTS
# ======================================================

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_gen.classes),
    y=train_gen.classes
)

class_weights = dict(enumerate(class_weights))

# ======================================================
# COSINE LR SCHEDULER
# ======================================================

lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=5e-5,
    decay_steps=EPOCHS * len(train_gen),
)

optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)

# ======================================================
# SAVE ONLY BEST MODEL
# ======================================================

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=os.path.join(output_dir, "densenet121_best.h5"),
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

# ======================================================
# TRAIN (ALL EPOCHS RUN)
# ======================================================

history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=EPOCHS,
    class_weight=class_weights,
    callbacks=[checkpoint],
    verbose=1
)

# ======================================================
# LOAD BEST MODEL
# ======================================================

best_model = tf.keras.models.load_model(
    os.path.join(output_dir, "densenet121_best.h5")
)

# ======================================================
# TEST EVALUATION
# ======================================================

test_loss, test_accuracy = best_model.evaluate(test_gen)
print("\nFinal Test Accuracy:", test_accuracy)

preds = best_model.predict(test_gen)
y_pred = np.argmax(preds, axis=1)
y_true = test_gen.classes

print("\nClassification Report:\n")
print(classification_report(
    y_true,
    y_pred,
    target_names=test_gen.class_indices.keys()
))

# ======================================================
# CONFUSION MATRIX
# ======================================================

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(6,6))
sns.heatmap(cm, annot=True, fmt='d',
            xticklabels=test_gen.class_indices.keys(),
            yticklabels=test_gen.class_indices.keys())
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.savefig(os.path.join(output_dir, "confusion_matrix.png"))
plt.show()

# ======================================================
# SAVE TRAINING CURVES
# ======================================================

plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.legend()
plt.title("Accuracy Curve")
plt.savefig(os.path.join(output_dir, "accuracy_curve.png"))
plt.show()

# ======================================================
# RANDOM IMAGE TESTING
# ======================================================

class_labels = list(test_gen.class_indices.keys())

for i in random.sample(range(len(test_gen.filepaths)), 5):
    img_path = test_gen.filepaths[i]
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=(IMG_SIZE, IMG_SIZE))
    img_array = tf.keras.preprocessing.image.img_to_array(img)/255.0
    img_array = np.expand_dims(img_array, axis=0)

    prediction = best_model.predict(img_array)
    predicted_class = class_labels[np.argmax(prediction)]

    plt.imshow(img)
    plt.title(f"Predicted: {predicted_class}")
    plt.axis("off")
    plt.show()
# Out:
# Found 6939 images belonging to 3 classes.
# Found 1791 images belonging to 3 classes.
# Found 1794 images belonging to 3 classes.
# I0000 00:00:1771739099.403638      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1771739099.409687      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/70
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771739157.486416     158 service.cc:152] XLA service 0x7929a0006060 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1771739157.486468     158 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1771739157.486473     158 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1771739167.772938     158 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1771739265.966896     158 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6017 - loss: 2.4727
# Epoch 1: val_accuracy improved from -inf to 0.22725, saving model to /kaggle/working/densenet121_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 450s 1s/step - accuracy: 0.6023 - loss: 2.4719 - val_accuracy: 0.2272 - val_loss: 3.1391
# Epoch 2/70
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.8065 - loss: 2.1629
# Epoch 2: val_accuracy improved from 0.22725 to 0.48130, saving model to /kaggle/working/densenet121_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 95s 435ms/step - accuracy: 0.8065 - loss: 2.1629 - val_accuracy: 0.4813 - val_loss: 2.9049
# Epoch 3/70
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.8441 - loss: 2.1145
# Epoch 3: val_accuracy improved from 0.48130 to 0.65550, saving model to /kaggle/working/densenet121_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 93s 427ms/step - accuracy: 0.8441 - loss: 2.1144 - val_accuracy: 0.6555 - val_loss: 2.5426
# Epoch 4/70
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.8678 - loss: 2.0672
# Epoch 4: val_accuracy did not improve from 0.65550
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 93s 426ms/step - accuracy: 0.8678 - loss: 2.0671 - val_accuracy: 0.5394 - val_loss: 2.8017
# Epoch 5/70
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.8873 - loss: 2.0263
# Epoch 5: val_accuracy improved from 0.65550 to 0.71301, saving model to /kaggle/working/densenet121_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 92s 423ms/step - accuracy: 0.8873 - loss: 2.0262 - val_accuracy: 0.7130 - val_loss: 2.3639
# Epoch 6/70
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.8943 - loss: 1.9975
# Epoch 6: val_accuracy did not improve from 0.71301
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 90s 412ms/step - accuracy: 0.8943 - loss: 1.9975 - val_accuracy: 0.3300 - val_loss: 3.4046
# Epoch 7/70
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.9065 - loss: 1.9710
# Epoch 7: val_accuracy did not improve from 0.71301
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 90s 413ms/step - accuracy: 0.9064 - loss: 1.9711 - val_accuracy: 0.5131 - val_loss: 2.5670
# Epoch 8/70
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.9051 - loss: 1.9552
# Epoch 8: val_accuracy did not improve from 0.71301
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 90s 412ms/step - accuracy: 0.9051 - loss: 1.9552 - val_accuracy: 0.6443 - val_loss: 2.3120
# Epoch 9/70
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.9252 - loss: 1.9243
# Epoch 9: val_accuracy did not improve from 0.71301
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 88s 406ms/step - accuracy: 0.9252 - loss: 1.9243 - val_accuracy: 0.4115 - val_loss: 2.9546
# Epoch 10/70
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.9245 - loss: 1.9118
# Epoch 10: val_accuracy did not improve from 0.71301
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 102s 468ms/step - accuracy: 0.9245 - loss: 1.9118 - val_accuracy: 0.3596 - val_loss: 3.4169
# Epoch 11/70
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - accuracy: 0.9298 - loss: 1.8958
# Epoch 11: val_accuracy did not improve from 0.71301
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 91s 418ms/step - accuracy: 0.9299 - loss: 1.8958 - val_accuracy: 0.6689 - val_loss: 2.4253
# Epoch 12/70
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.9278 - loss: 1.8876
# Epoch 12: val_accuracy did not improve from 0.71301
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 90s 414ms/step - accuracy: 0.9278 - loss: 1.8875 - val_accuracy: 0.7069 - val_loss: 2.5225
# Epoch 13/70
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.9452 - loss: 1.8580
# Epoch 13: val_accuracy improved from 0.71301 to 0.79174, saving model to /kaggle/working/densenet121_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 91s 419ms/step - accuracy: 0.9451 - loss: 1.8580 - val_accuracy: 0.7917 - val_loss: 2.1029
# Epoch 14/70
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.9518 - loss: 1.8369
# Epoch 14: val_accuracy did not improve from 0.79174
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 90s 413ms/step - accuracy: 0.9518 - loss: 1.8369 - val_accuracy: 0.6013 - val_loss: 2.4398
# Epoch 15/70
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.